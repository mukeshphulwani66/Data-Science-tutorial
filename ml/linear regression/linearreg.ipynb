# %%
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("salary.csv")

# %%
df
# Out:
#    Experience  Salary
# 0           1   10000
# 1           3   21000
# 2           4   45000
# 3           5   41000
# 4           7   50000
# 5           8   72000
# 6          10   90000
# 7          11   95000
# 8          12  120000
# 9          15  150000

# %%
plt.scatter(df["Experience"],df["Salary"])
plt.xlabel("experience")
plt.ylabel("Salary")
# Out:
# Text(0, 0.5, 'Salary')

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(df[["Experience"]],df["Salary"],test_size=0.3)

# %%
reg = LinearRegression()

# %%
reg.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
xtest
# Out:
#    Experience
# 7          11
# 2           4
# 1           3

# %%
ytest
# Out:
# 7    95000
# 2    45000
# 1    21000
# Name: Salary, dtype: int64

# %%
reg.predict(xtest)
# Out:
# array([104146.86098655,  31926.00896861,  21608.74439462])

# %%
reg.coef_
# Out:
# array([9086.8902439])

# %%
reg.intercept_
# Out:
# 56.40243902440125

# %%
# Y = mx + c
9890.02267574 * 9 + -5764.172335600917
# Out:
# 83246.03174605907

# %%
import seaborn as sns
sns.regplot(x="Experience",y="Salary",data=df)

# %%
reg.score(xtest,ytest)
# Out:
# 0.9105595613421186
