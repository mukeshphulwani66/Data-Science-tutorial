# %%
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn.linear_model import LogisticRegression 
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("exam.csv")

# %%
df.head()
# Out:
#    Hr  Result
# 0   1       0
# 1   2       0
# 2   3       0
# 3   4       1
# 4   5       0

# %%
plt.scatter(df["Hr"],df["Result"])

# %%
xtrain,xtest,ytrain,ytest=train_test_split(df[["Hr"]],df["Result"],test_size=0.4)

# %%
classifier = LogisticRegression()

# %%
classifier.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
xtest
# Out:
#    Hr
# 9  20
# 1   2
# 7  13
# 4   5

# %%
ytest
# Out:
# 9    1
# 1    0
# 7    1
# 4    0
# Name: Result, dtype: int64

# %%
ypredicted  = classifier.predict(xtest)

# %%
classifier.score(xtest,ytest)
# Out:
# 0.75

# %%
classifier.predict_proba(xtest)
# Out:
# array([[8.51306886e-07, 9.99999149e-01],
#        [7.96638573e-01, 2.03361427e-01],
#        [3.31949891e-04, 9.99668050e-01],
#        [2.32978529e-01, 7.67021471e-01]])

# %%
from sklearn.metrics import confusion_matrix,plot_confusion_matrix
cm = confusion_matrix(ytest,ypredicted)

# %%
cm
# Out:
# array([[1, 1],
#        [0, 2]], dtype=int64)

# %%
plot_confusion_matrix(classifier,xtest,ytest)
